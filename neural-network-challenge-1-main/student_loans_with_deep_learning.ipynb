# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
# %pip install scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\jieja\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.2-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.0 MB 8.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.0 MB 8.8 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.0 MB 9.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 11.4 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---- ----------------------------------- 4.7/44.5 MB 23.8 MB/s eta 0:00:02
#    ------- -------------------------------- 8.4/44.5 MB 20.0 MB/s eta 0:00:02
#    ------------ --------------------------- 13.4/44.5 MB 21.5 MB/s eta 0:00:02
#    --------------- ------------------------ 16.8/44.5 MB 20.3 MB/s eta 0:00:02
#    -------------------- ------------------- 22.5/44.5 MB 21.3 MB/s eta 0:00:02
#    ------------------------- -------------- 28.8/44.5 MB 23.5 MB/s eta 0:00:01
#    ------------------------------- -------- 35.4/44.5 MB 23.9 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.5 MB 24.7 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 24.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.copy()

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train[0])

# Define features_number
features_number = number_input_features

# Review the number of features
features_number
# Out:
# 12

# %%
# Define the number of hidden nodes for the first hidden layer
nodes_hidden_layer1 = 8

# Define the number of hidden nodes for the second hidden layer
nodes_hidden_layer1 = 5

# Define the number of neurons in the output layer
neurons_output_layer = 1

# %%
# Define the number of hidden nodes for the second hidden layer
nodes_hidden_layer2 = 5

# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

# Add the first hidden layer
nn_model.add(
    tf.keras.layers.Dense(units=nodes_hidden_layer1, input_dim=features_number, activation="relu")
)

# Add the second hidden layer
nn_model.add(tf.keras.layers.Dense(units=nodes_hidden_layer2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 8)              │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │            45 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 155 (620.00 B)
#  Trainable params: 155 (620.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)

# Compile the Sequential model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4727 - loss: 0.8001
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.4809 - loss: 0.7325
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.5028 - loss: 0.6945
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - accuracy: 0.6124 - loss: 0.6291
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.7287 - loss: 0.6143
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.8221 - loss: 0.5833
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.8689 - loss: 0.5654
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9230 - loss: 0.5382
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 0.9399 - loss: 0.5196
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9507 - loss: 0.4936
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.9711 - loss: 0.4770
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9752 - loss: 0.4467
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 0.9831 - loss: 0.4304
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.4035
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.9973 - loss: 0.3979
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9983 - loss: 0.3854
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9981 - loss: 0.3693
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9989 - loss: 0.3574
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.3492
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 1.0000 - loss: 0.3311
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 1.0000 - loss: 0.3246
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.31431
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 1.0000 - loss: 0.3050
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 1.0000 - loss: 0.3082
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 1.0000 - loss: 0.2955
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 1.0000 - loss: 0.2880
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 1.0000 - loss: 0.2833
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 1.0000 - loss: 0.2777
# Epoch 29/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 1.0000 - loss: 0.2709
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 1.0000 - loss: 0.2609
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 1.0000 - loss: 0.2581
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 1.0000 - loss: 0.2522
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 1.0000 - loss: 0.2459
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 1.0000 - loss: 0.2424
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 1.0000 - loss: 0.2365
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 1.0000 - loss: 0.2318
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 1.0000 - loss: 0.2304
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 1.0000 - loss: 0.2261
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 1.0000 - loss: 0.2226
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 1.0000 - loss: 0.2171
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 1.0000 - loss: 0.2120
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 1.0000 - loss: 0.2102
# Epoch 43/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 1.0000 - loss: 0.2078
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - accuracy: 1.0000 - loss: 0.2070
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 1.0000 - loss: 0.1990
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 1.0000 - loss: 0.2003
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 1.0000 - loss: 0.1936
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 1.0000 - loss: 0.1922
# Epoch 49/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - accuracy: 1.0000 - loss: 0.1893
# Epoch 50/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 1.0000 - loss: 0.1858

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Scale the test data
X_test_scaled = X_scaler.transform(X_test)

# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# Display the model loss and accuracy results
summary_df = pd.DataFrame({"model_loss": [model_loss],"model_accuracy":[model_accuracy]})
# Out:
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1822
# Loss: 0.1821577399969101, Accuracy: 1.0

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path =  Path("student_loans.keras")
# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path =  Path("student_loans.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_model.predict(X_test_scaled,verbose=2)


# Display a sample of the predictions
predictions
# Out:
# 13/13 - 0s - 5ms/step
# array([[0.12082837],
#        [0.7956836 ],
#        [0.7956925 ],
#        [0.7957612 ],
#        [0.79570925],
#        [0.7957646 ],
#        [0.7957553 ],
#        [0.12074467],
#        [0.12447495],
#        [0.12111888],
#        [0.7957479 ],
#        [0.79568565],
#        [0.79574937],
#        [0.7957658 ],
#        [0.7957448 ],
#        [0.12077835],
#        [0.7956476 ],
#        [0.12131322],
#        [0.12133674],
#        [0.12183205],
#        [0.7957148 ],
#        [0.7957615 ],
#        [0.12120163],
#        [0.79570764],
#        [0.7957044 ],
#        [0.79567116],
#        [0.79576206],
#        [0.7956541 ],
#        [0.7956783 ],
#        [0.7926885 ],
#        [0.795681  ],
#        [0.7957574 ],
#        [0.1208287 ],
#        [0.7957142 ],
#        [0.12075792],
#        [0.7957622 ],
#        [0.12125537],
#        [0.7957173 ],
#        [0.79575187],
#        [0.12089653],
#        [0.7957466 ],
#        [0.12074433],
#        [0.12139386],
#        [0.7957631 ],
#        [0.12079931],
#        [0.79576296],
#        [0.1212339 ],
#        [0.12117512],
#        [0.1207802 ],
#        [0.7957496 ],
#        [0.12103515],
#        [0.12128109],
#        [0.79575557],
#        [0.12071583],
#        [0.12078005],
#        [0.7957664 ],
#        [0.7957284 ],
#        [0.79576254],
#        [0.12642664],
#        [0.12106883],
#        [0.12187496],
#        [0.795662  ],
#        [0.1208954 ],
#        [0.7956049 ],
#        [0.12072241],
#        [0.79571724],
#        [0.79565084],
#        [0.79568136],
#        [0.7956833 ],
#        [0.7957121 ],
#        [0.12075792],
#        [0.7957389 ],
#        [0.79569745],
#        [0.7957572 ],
#        [0.12119279],
#        [0.12112939],
#        [0.7957018 ],
#        [0.7956008 ],
#        [0.12085078],
#        [0.79567474],
#        [0.12275387],
#        [0.12071393],
#        [0.12074552],
#        [0.7954308 ],
#        [0.12157866],
#        [0.12072785],
#        [0.12075242],
#        [0.79576313],
#        [0.12162142],
#        [0.7957628 ],
#        [0.12077277],
#        [0.795761  ],
#        [0.12138002],
#        [0.7956851 ],
#        [0.1241663 ],
#        [0.12134822],
#        [0.7957458 ],
#        [0.12174703],
#        [0.12113556],
#        [0.79575485],
#        [0.12147103],
#        [0.12097409],
#        [0.12077007],
#        [0.12070463],
#        [0.12077605],
#        [0.1210706 ],
#        [0.7957658 ],
#        [0.79569495],
#        [0.12282591],
#        [0.7901057 ],
#        [0.7950669 ],
#        [0.12113818],
#        [0.79568356],
#        [0.79566944],
#        [0.12121771],
#        [0.7957645 ],
#        [0.12076218],
#        [0.12077914],
#        [0.12094112],
#        [0.12104407],
#        [0.12092418],
#        [0.7956702 ],
#        [0.79576087],
#        [0.12098761],
#        [0.12134942],
#        [0.12129439],
#        [0.79574287],
#        [0.12102483],
#        [0.7957667 ],
#        [0.7957602 ],
#        [0.7957642 ],
#        [0.12075646],
#        [0.79573095],
#        [0.12074795],
#        [0.79573786],
#        [0.7957496 ],
#        [0.12130385],
#        [0.7957221 ],
#        [0.7955352 ],
#        [0.79573977],
#        [0.12084313],
#        [0.79572946],
#        [0.7956637 ],
#        [0.1208731 ],
#        [0.7957665 ],
#        [0.7957572 ],
#        [0.79572964],
#        [0.12075117],
#        [0.7957479 ],
#        [0.7957271 ],
#        [0.79569095],
#        [0.7957501 ],
#        [0.12071076],
#        [0.7956023 ],
#        [0.12427952],
#        [0.7957183 ],
#        [0.12708126],
#        [0.7956854 ],
#        [0.7957679 ],
#        [0.79572195],
#        [0.79572445],
#        [0.79575557],
#        [0.12080144],
#        [0.12071841],
#        [0.79568005],
#        [0.7957605 ],
#        [0.12119866],
#        [0.12072775],
#        [0.12077375],
#        [0.7957536 ],
#        [0.79565054],
#        [0.7957528 ],
#        [0.12093835],
#        [0.79521096],
#        [0.12630317],
#        [0.795673  ],
#        [0.12099091],
#        [0.12105388],
#        [0.1209411 ],
#        [0.12134822],
#        [0.7957478 ],
#        [0.79575825],
#        [0.12093513],
#        [0.7860439 ],
#        [0.7957457 ],
#        [0.79571927],
#        [0.7957374 ],
#        [0.79574937],
#        [0.12166214],
#        [0.79526573],
#        [0.1220669 ],
#        [0.7957516 ],
#        [0.79573214],
#        [0.12100553],
#        [0.79574114],
#        [0.12133197],
#        [0.12102088],
#        [0.12253673],
#        [0.7957517 ],
#        [0.12150778],
#        [0.7957452 ],
#        [0.12120167],
#        [0.79569435],
#        [0.12073825],
#        [0.7957499 ],
#        [0.79575104],
#        [0.12160251],
#        [0.12079653],
#        [0.79557896],
#        [0.12174761],
#        [0.12255955],
#        [0.79563653],
#        [0.12077007],
#        [0.79573554],
#        [0.12081637],
#        [0.79556817],
#        [0.12087411],
#        [0.12068627],
#        [0.795765  ],
#        [0.7955961 ],
#        [0.12235618],
#        [0.7957129 ],
#        [0.12136649],
#        [0.12080597],
#        [0.79574895],
#        [0.12125108],
#        [0.12192837],
#        [0.7957577 ],
#        [0.7957457 ],
#        [0.795402  ],
#        [0.79558843],
#        [0.7955226 ],
#        [0.79574805],
#        [0.7957152 ],
#        [0.7952304 ],
#        [0.7869686 ],
#        [0.7957436 ],
#        [0.7953491 ],
#        [0.12221378],
#        [0.121735  ],
#        [0.79574   ],
#        [0.12495786],
#        [0.7957607 ],
#        [0.7957308 ],
#        [0.7957412 ],
#        [0.7957498 ],
#        [0.79571855],
#        [0.12180712],
#        [0.12145779],
#        [0.12151806],
#        [0.12088268],
#        [0.12091501],
#        [0.79573864],
#        [0.795755  ],
#        [0.79569215],
#        [0.12086621],
#        [0.12075197],
#        [0.12096271],
#        [0.12076265],
#        [0.12311999],
#        [0.7957435 ],
#        [0.12156036],
#        [0.1225495 ],
#        [0.12122291],
#        [0.12081121],
#        [0.7957479 ],
#        [0.12175494],
#        [0.12081424],
#        [0.7899525 ],
#        [0.7957366 ],
#        [0.12113909],
#        [0.7957628 ],
#        [0.12075453],
#        [0.7957613 ],
#        [0.795128  ],
#        [0.121512  ],
#        [0.12098566],
#        [0.7957528 ],
#        [0.12111983],
#        [0.12082995],
#        [0.79560757],
#        [0.1213619 ],
#        [0.12188917],
#        [0.12076606],
#        [0.79536206],
#        [0.1213176 ],
#        [0.7955911 ],
#        [0.12099101],
#        [0.12131546],
#        [0.12109548],
#        [0.7957411 ],
#        [0.7956476 ],
#        [0.7957344 ],
#        [0.12101114],
#        [0.7957393 ],
#        [0.79576445],
#        [0.12073666],
#        [0.12370825],
#        [0.12082932],
#        [0.1209458 ],
#        [0.79573387],
#        [0.79569423],
#        [0.12073029],
#        [0.12126226],
#        [0.7957532 ],
#        [0.7957479 ],
#        [0.12077057],
#        [0.13148977],
#        [0.12198802],
#        [0.12072749],
#        [0.12123317],
#        [0.12166716],
#        [0.79501927],
#        [0.7957265 ],
#        [0.79552466],
#        [0.12113605],
#        [0.12074314],
#        [0.1209866 ],
#        [0.79572356],
#        [0.7957436 ],
#        [0.79567313],
#        [0.12277047],
#        [0.7956868 ],
#        [0.12074722],
#        [0.12133197],
#        [0.12084845],
#        [0.12104419],
#        [0.7957129 ],
#        [0.12180275],
#        [0.7957697 ],
#        [0.7906375 ],
#        [0.7950668 ],
#        [0.12130167],
#        [0.79576194],
#        [0.79573375],
#        [0.79560196],
#        [0.7957029 ],
#        [0.79573554],
#        [0.12075902],
#        [0.7956935 ],
#        [0.12189727],
#        [0.79573   ],
#        [0.79569006],
#        [0.79549384],
#        [0.1210743 ],
#        [0.7957064 ],
#        [0.79576325],
#        [0.1207018 ],
#        [0.12101069],
#        [0.12220828],
#        [0.79563653],
#        [0.7957345 ],
#        [0.12198301],
#        [0.13733232],
#        [0.79576004],
#        [0.12095191],
#        [0.79570055],
#        [0.7957658 ],
#        [0.12130385],
#        [0.12077186],
#        [0.12076637],
#        [0.795759  ],
#        [0.12088352],
#        [0.7957439 ],
#        [0.1217929 ],
#        [0.12075005],
#        [0.12121001],
#        [0.12074939],
#        [0.12096953],
#        [0.7869686 ],
#        [0.7957594 ],
#        [0.79576117],
#        [0.7957177 ],
#        [0.12087221],
#        [0.12074167],
#        [0.7957463 ],
#        [0.79565823],
#        [0.79571563],
#        [0.79556817],
#        [0.7957432 ],
#        [0.7957417 ],
#        [0.7957177 ],
#        [0.7956262 ],
#        [0.12147922],
#        [0.7954259 ],
#        [0.7956539 ],
#        [0.12068989],
#        [0.7957503 ],
#        [0.7957021 ],
#        [0.79576075],
#        [0.7955095 ],
#        [0.7953057 ],
#        [0.12130617],
#        [0.79571605],
#        [0.12173403],
#        [0.12177745],
#        [0.12162142],
#        [0.79574805],
#        [0.1207658 ],
#        [0.7957458 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            0.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          0.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       188
#            1       1.00      1.00      1.00       212
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
